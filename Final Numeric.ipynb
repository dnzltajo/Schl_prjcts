# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

plt.style.use('seaborn-poster')
x=np.arange(1,43)
y1=np.array([15,19,15,22,35,31,27,25,32,21,11,5,7,18,17,23,20,22,19,17,19,22,23,19,24,14,15,19,23,20,16,19,17,21,15,12,14,11,12,15,21,19])
y2=np.array([9,11,7,9,20,7,11,15,29,17,8,8,9,16,12,10,19,12,12,24,34,10,7,6,9,19,10,7,17,18,14,18,38,13,17,26,18,25,22,20,31,16])
y3=np.array([25,22,24,21,19,19,21,16,22,20,22,21,22,16,21,16,16,21,23,27,56,33,20,28,31,39,33,11,6,12,12,32,49,37,29,34,31,32,31,21,21,21])
y4=np.array([9,9,11,9,21,11,9,8,7,6,9,6,7,5,6,7,6,5,7,5,4,4,3,5,4,4,7,11,8,10,7,8,6,8,7,9,9,7,7,6,11,10])
y5=np.array([23,0,14,19,14,28,23,28,26,12,21,19,18,19,20,19,19,16,18,17,13,20,14,14,10,22,42,21,20,11,8,7,7,12,8,9,9,9,7,5,13,10])
y6=np.array([14,3,21,22,16,17,15,18,19,17,14,19,21,20,20,14,9,9,7,6,11,11,7,5,1,12,16,9,6,7,7,0,2,5,11,13,14,15,14,13,13,14])
y7=np.array([64,58,58,46,66,60,52,94,110,112,86,80,87,76,72,55,80,67,73,88,116,94,54,84,98,102,100,78,75,90,66,76,97,95,86,96,93,91,77,83,78,76])
y8=np.array([52,58,52,44,48,46,45,57,95,120,90,60,86,120,20,61,66,51,48,50,75,86,28,48,64,61,64,35,54,50,58,76,75,78,65,42,46,52,53,43,62,38])
y9=np.array([248,238,263,218,220,206,182,204,214,217,183,220,189,188,186,209,209,209,212,249,253,222,128,209,191,221,198,193,226,197,196,286,258,233,222,202,220,237,266,297,170,169])
y10=np.array([76,74,77,51,68,75,62,84,104,62,70,78,52,82,72,60,82,66,68,131,107,130,55,76,80,82,87,68,88,69,85,24,63,75,71,82,87,83,119,95,70,39])
plt.figure(1)
plt.plot(x,y1,label='House 1')
plt.plot(x,y2,label='House 2')
plt.plot(x,y3,label='House 3')
plt.plot(x,y4,label='House 4')
plt.plot(x,y5,label='House 5')
plt.plot(x,y6,label='House 6')
plt.plot(x,y7,label='House 7')
plt.plot(x,y8,label='House 8')
plt.plot(x,y9,label='House 9')
plt.plot(x,y10,label='House 10')
plt.title('Household Electric Power Consumption')
plt.xlabel('Month')
plt.ylabel('Power Consumption (kWh)')
plt.legend()
plt.show()

# %%
#house 1
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import statistics as st

plt.style.use('seaborn-poster')

x1=np.arange(1,43)
x2=np.arange(7,43)

y_init=[15,19,15,22,35,31]
y_test=[27,25,32,21,11,5,7,18,17,23,20,22,19,17,19,22,23,19,24,14,15,19,23,20,16,19,17,21,15,12,14,11,12,15,21,19]
yset=[15,19,15,22,35,31,27,25,32,21,11,5,7,18,17,23,20,22,19,17,19,22,23,19,24,14,15,19,23,20,16,19,17,21,15,12,14,11,12,15,21,19]
ez=[]
yx=[]
for i in range(0,36):
    z = np.polyfit(x1[i:6+i],y_init, 1)
    p = np.poly1d(z)
    y_init.append(y_test[i])
    y_init[0:6]=list(y_init[1:6])
    ez.append(p(6+i))
    print(y_init) 
std=st.stdev(yset)
print('Std Dev:%.16f'%std)
er=np.subtract(y_test,ez)
mae = mean_absolute_error(y_test, ez)
print('MAE: %f kwh' % mae)
mse =mean_squared_error(y_test,ez)
print('MSE:%.16f'%mse)
plt.scatter(x2,y_test,marker='o',color='black',label='Actual')
plt.xlabel('Month')
plt.ylabel('kWh')
plt.title('Household 1 Predicted Consumption')
plt.plot(x2,ez,'--Xb',label='Predicted')
er=np.subtract(y_test,ez)

plt.show()
# Out:
# [19, 15, 22, 35, 31, 27]
# [15, 22, 35, 31, 27, 25]
# [22, 35, 31, 27, 25, 32]
# [35, 31, 27, 25, 32, 21]
# [31, 27, 25, 32, 21, 11]
# [27, 25, 32, 21, 11, 5]
# [25, 32, 21, 11, 5, 7]
# [32, 21, 11, 5, 7, 18]
# [21, 11, 5, 7, 18, 17]
# [11, 5, 7, 18, 17, 23]
# [5, 7, 18, 17, 23, 20]
# [7, 18, 17, 23, 20, 22]
# [18, 17, 23, 20, 22, 19]
# [17, 23, 20, 22, 19, 17]
# [23, 20, 22, 19, 17, 19]
# [20, 22, 19, 17, 19, 22]
# [22, 19, 17, 19, 22, 23]
# [19, 17, 19, 22, 23, 19]
# [17, 19, 22, 23, 19, 24]
# [19, 22, 23, 19, 24, 14]
# [22, 23, 19, 24, 14, 15]
# [23, 19, 24, 14, 15, 19]
# [19, 24, 14, 15, 19, 23]
# [24, 14, 15, 19, 23, 20]
# [14, 15, 19, 23, 20, 16]
# [15, 19, 23, 20, 16, 19]
# [19, 23, 20, 16, 19, 17]
# [23, 20, 16, 19, 17, 21]
# [20, 16, 19, 17, 21, 15]
# [16, 19, 17, 21, 15, 12]
# [19, 17, 21, 15, 12, 14]
# [17, 21, 15, 12, 14, 11]
# [21, 15, 12, 14, 11, 12]
# [15, 12, 14, 11, 12, 15]
# [12, 14, 11, 12, 15, 21]
# [14, 11, 12, 15, 21, 19]
# Std Dev:6.0482477473238587
# ...

# %%
#house 2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import statistics as st

plt.style.use('seaborn-poster')

x1=np.arange(1,43)
x2=np.arange(13,43)

y_init=[9,11,7,9,20,7,11,15,29,17,8,8]
y_test=[9,16,12,10,19,12,12,24,34,10,7,6,9,19,10,7,17,18,14,18,38,13,17,26,18,25,22,20,31,16]
yset=[9,11,7,9,20,7,11,15,29,17,8,8,9,16,12,10,19,12,12,24,34,10,7,6,9,19,10,7,17,18,14,18,38,13,17,26,18,25,22,20,31,16]
ez=[]

for i in range(0,30):
    z = np.polyfit(x1[i:12+i],y_init, 1)
    p = np.poly1d(z)
    y_init.append(y_test[i])
    y_init[0:12]=list(y_init[1:12])
    ez.append(p(12+i))
    print(y_init)
    
std=st.stdev(yset)
print('Std Dev:%.16f'%std)        
mae = mean_absolute_error(y_test, ez)
print('MAE: %f kwh' % mae)
mse =mean_squared_error(y_test,ez)
print('MSE:%.16f'%mse)
plt.scatter(x2,y_test,marker='o',color='black',label='Actual')
plt.xlabel('Month')
plt.ylabel('kWh')
plt.title('Household 2 Predicted Consumption')
plt.plot(x2,ez,'--Xb',label='Predicted')
er=np.subtract(y_test,ez)
plt.figure(2)
plt.plot(x2,er,'-Xk',label='Error')
plt.legend()
plt.show()
# Out:
# [11, 7, 9, 20, 7, 11, 15, 29, 17, 8, 8, 9]
# [7, 9, 20, 7, 11, 15, 29, 17, 8, 8, 9, 16]
# [9, 20, 7, 11, 15, 29, 17, 8, 8, 9, 16, 12]
# [20, 7, 11, 15, 29, 17, 8, 8, 9, 16, 12, 10]
# [7, 11, 15, 29, 17, 8, 8, 9, 16, 12, 10, 19]
# [11, 15, 29, 17, 8, 8, 9, 16, 12, 10, 19, 12]
# [15, 29, 17, 8, 8, 9, 16, 12, 10, 19, 12, 12]
# [29, 17, 8, 8, 9, 16, 12, 10, 19, 12, 12, 24]
# [17, 8, 8, 9, 16, 12, 10, 19, 12, 12, 24, 34]
# [8, 8, 9, 16, 12, 10, 19, 12, 12, 24, 34, 10]
# [8, 9, 16, 12, 10, 19, 12, 12, 24, 34, 10, 7]
# [9, 16, 12, 10, 19, 12, 12, 24, 34, 10, 7, 6]
# [16, 12, 10, 19, 12, 12, 24, 34, 10, 7, 6, 9]
# [12, 10, 19, 12, 12, 24, 34, 10, 7, 6, 9, 19]
# [10, 19, 12, 12, 24, 34, 10, 7, 6, 9, 19, 10]
# [19, 12, 12, 24, 34, 10, 7, 6, 9, 19, 10, 7]
# [12, 12, 24, 34, 10, 7, 6, 9, 19, 10, 7, 17]
# [12, 24, 34, 10, 7, 6, 9, 19, 10, 7, 17, 18]
# [24, 34, 10, 7, 6, 9, 19, 10, 7, 17, 18, 14]
# [34, 10, 7, 6, 9, 19, 10, 7, 17, 18, 14, 18]
# [10, 7, 6, 9, 19, 10, 7, 17, 18, 14, 18, 38]
# ...

# %%
#house 3
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import statistics as st
plt.style.use('seaborn-poster')

x1=np.arange(1,43)
x2=np.arange(13,43)

y_init=[25,22,24,21,19,19,21,16,22,20,22,21]
y_test=[22,16,21,16,16,21,23,27,56,33,20,28,31,39,33,11,6,12,12,32,49,37,29,34,31,32,31,21,21,21]
yset=[25,22,24,21,19,19,21,16,22,20,22,21,22,16,21,16,16,21,23,27,56,33,20,28,31,39,33,11,6,12,12,32,49,37,29,34,31,32,31,21,21,21]
ez=[]
yx=[]
for i in range(0,30):
    z = np.polyfit(x1[i:12+i],y_init, 1)
    p = np.poly1d(z)
    y_init.append(y_test[i])
    y_init[0:12]=list(y_init[1:12])
    ez.append(p(12+i))
    print(y_init)
    
std=st.stdev(yset)
print('Std Dev:%.16f'%std)  
mae = mean_absolute_error(y_test, ez)
print('MAE: %f kwh' % mae)
mse =mean_squared_error(y_test,ez)
print('MSE:%.16f'%mse)
plt.scatter(x2,y_test,marker='o',color='black',label='Actual')
plt.xlabel('Month')
plt.ylabel('kWh')
plt.title('Household 3 Predicted Consumption')
plt.plot(x2,ez,'--Xb',label='Predicted')
er=np.subtract(y_test,ez)
plt.figure(2)
plt.plot(x2,er,'-Xk',label='Error')
plt.legend()
plt.show()
# Out:
# [22, 24, 21, 19, 19, 21, 16, 22, 20, 22, 21, 22]
# [24, 21, 19, 19, 21, 16, 22, 20, 22, 21, 22, 16]
# [21, 19, 19, 21, 16, 22, 20, 22, 21, 22, 16, 21]
# [19, 19, 21, 16, 22, 20, 22, 21, 22, 16, 21, 16]
# [19, 21, 16, 22, 20, 22, 21, 22, 16, 21, 16, 16]
# [21, 16, 22, 20, 22, 21, 22, 16, 21, 16, 16, 21]
# [16, 22, 20, 22, 21, 22, 16, 21, 16, 16, 21, 23]
# [22, 20, 22, 21, 22, 16, 21, 16, 16, 21, 23, 27]
# [20, 22, 21, 22, 16, 21, 16, 16, 21, 23, 27, 56]
# [22, 21, 22, 16, 21, 16, 16, 21, 23, 27, 56, 33]
# [21, 22, 16, 21, 16, 16, 21, 23, 27, 56, 33, 20]
# [22, 16, 21, 16, 16, 21, 23, 27, 56, 33, 20, 28]
# [16, 21, 16, 16, 21, 23, 27, 56, 33, 20, 28, 31]
# [21, 16, 16, 21, 23, 27, 56, 33, 20, 28, 31, 39]
# [16, 16, 21, 23, 27, 56, 33, 20, 28, 31, 39, 33]
# [16, 21, 23, 27, 56, 33, 20, 28, 31, 39, 33, 11]
# [21, 23, 27, 56, 33, 20, 28, 31, 39, 33, 11, 6]
# [23, 27, 56, 33, 20, 28, 31, 39, 33, 11, 6, 12]
# [27, 56, 33, 20, 28, 31, 39, 33, 11, 6, 12, 12]
# ...

# %%
#house 4
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import statistics as st
plt.style.use('seaborn-poster')

x1=np.arange(1,43)
x2=np.arange(13,43)

y_init=[9,9,11,9,21,11,9,8,7,6,9,6]
y_test=[7,5,6,7,6,5,7,5,4,4,3,5,4,4,7,11,8,10,7,8,6,8,7,9,9,7,7,6,11,10]
yset=[9,9,11,9,21,11,9,8,7,6,9,6,7,5,6,7,6,5,7,5,4,4,3,5,4,4,7,11,8,10,7,8,6,8,7,9,9,7,7,6,11,10]
ez=[]
yx=[]
for i in range(0,30):
    z = np.polyfit(x1[i:12+i],y_init, 1)
    p = np.poly1d(z)
    y_init.append(y_test[i])
    y_init[0:12]=list(y_init[1:12])
    ez.append(p(12+i))
    print(y_init)
print(p(43))    
std=st.stdev(yset)
print('Std Dev:%.16f'%std)  
mae = mean_absolute_error(y_test, ez)
print('MAE: %f kwh' % mae)
mse =mean_squared_error(y_test,ez)
print('MSE:%.16f'%mse)
plt.scatter(x2,y_test,marker='o',color='black',label='Actual')
plt.xlabel('Month')
plt.ylabel('kWh')
plt.title('Household 4 Predicted Consumption')
plt.plot(x2,ez,'--Xb',label='Predicted')
er=np.subtract(y_test,ez)
plt.figure(2)
plt.plot(x2,er,'-Xk',label='Error')
plt.legend()
plt.show()
# Out:
# [9, 11, 9, 21, 11, 9, 8, 7, 6, 9, 6, 7]
# [11, 9, 21, 11, 9, 8, 7, 6, 9, 6, 7, 5]
# [9, 21, 11, 9, 8, 7, 6, 9, 6, 7, 5, 6]
# [21, 11, 9, 8, 7, 6, 9, 6, 7, 5, 6, 7]
# [11, 9, 8, 7, 6, 9, 6, 7, 5, 6, 7, 6]
# [9, 8, 7, 6, 9, 6, 7, 5, 6, 7, 6, 5]
# [8, 7, 6, 9, 6, 7, 5, 6, 7, 6, 5, 7]
# [7, 6, 9, 6, 7, 5, 6, 7, 6, 5, 7, 5]
# [6, 9, 6, 7, 5, 6, 7, 6, 5, 7, 5, 4]
# [9, 6, 7, 5, 6, 7, 6, 5, 7, 5, 4, 4]
# [6, 7, 5, 6, 7, 6, 5, 7, 5, 4, 4, 3]
# [7, 5, 6, 7, 6, 5, 7, 5, 4, 4, 3, 5]
# [5, 6, 7, 6, 5, 7, 5, 4, 4, 3, 5, 4]
# [6, 7, 6, 5, 7, 5, 4, 4, 3, 5, 4, 4]
# [7, 6, 5, 7, 5, 4, 4, 3, 5, 4, 4, 7]
# [6, 5, 7, 5, 4, 4, 3, 5, 4, 4, 7, 11]
# [5, 7, 5, 4, 4, 3, 5, 4, 4, 7, 11, 8]
# [7, 5, 4, 4, 3, 5, 4, 4, 7, 11, 8, 10]
# [5, 4, 4, 3, 5, 4, 4, 7, 11, 8, 10, 7]
# [4, 4, 3, 5, 4, 4, 7, 11, 8, 10, 7, 8]
# [4, 3, 5, 4, 4, 7, 11, 8, 10, 7, 8, 6]
# [3, 5, 4, 4, 7, 11, 8, 10, 7, 8, 6, 8]
# [5, 4, 4, 7, 11, 8, 10, 7, 8, 6, 8, 7]
# [4, 4, 7, 11, 8, 10, 7, 8, 6, 8, 7, 9]
# ...

# %%
#house 5
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import statistics as st
plt.style.use('seaborn-poster')

x1=np.arange(1,43)
x2=np.arange(13,43)

y_init=[23,0,14,19,14,28,23,28,26,12,21,19]
y_test=[18,19,20,19,19,16,18,17,13,20,14,14,10,22,42,21,20,11,8,7,7,12,8,9,9,9,7,5,13,10]
yset=[23,0,14,19,14,28,23,28,26,12,21,19,18,19,20,19,19,16,18,17,13,20,14,14,10,22,42,21,20,11,8,7,7,12,8,9,9,9,7,5,13,10]
ez=[]
yx=[]
for i in range(0,30):
    z = np.polyfit(x1[i:12+i],y_init, 1)
    p = np.poly1d(z)
    y_init.append(y_test[i])
    y_init[0:12]=list(y_init[1:12])
    ez.append(p(12+i))
    print(y_init)
std=st.stdev(yset)
print('Std Dev:%.16f'%std)  
mae = mean_absolute_error(y_test, ez)
print('MAE: %f kwh' % mae)
mse =mean_squared_error(y_test,ez)
print('MSE:%.16f'%mse)
plt.scatter(x2,y_test,marker='o',color='black',label='Actual')
plt.xlabel('Month')
plt.ylabel('kWh')
plt.title('Household 5 Predicted Consumption')
plt.plot(x2,ez,'--Xb',label='Predicted')
er=np.subtract(y_test,ez)
plt.figure(2)
plt.plot(x2,er,'-Xk',label='Error')
plt.legend()
plt.show()
# Out:
# [0, 14, 19, 14, 28, 23, 28, 26, 12, 21, 19, 18]
# [14, 19, 14, 28, 23, 28, 26, 12, 21, 19, 18, 19]
# [19, 14, 28, 23, 28, 26, 12, 21, 19, 18, 19, 20]
# [14, 28, 23, 28, 26, 12, 21, 19, 18, 19, 20, 19]
# [28, 23, 28, 26, 12, 21, 19, 18, 19, 20, 19, 19]
# [23, 28, 26, 12, 21, 19, 18, 19, 20, 19, 19, 16]
# [28, 26, 12, 21, 19, 18, 19, 20, 19, 19, 16, 18]
# [26, 12, 21, 19, 18, 19, 20, 19, 19, 16, 18, 17]
# [12, 21, 19, 18, 19, 20, 19, 19, 16, 18, 17, 13]
# [21, 19, 18, 19, 20, 19, 19, 16, 18, 17, 13, 20]
# [19, 18, 19, 20, 19, 19, 16, 18, 17, 13, 20, 14]
# [18, 19, 20, 19, 19, 16, 18, 17, 13, 20, 14, 14]
# [19, 20, 19, 19, 16, 18, 17, 13, 20, 14, 14, 10]
# [20, 19, 19, 16, 18, 17, 13, 20, 14, 14, 10, 22]
# [19, 19, 16, 18, 17, 13, 20, 14, 14, 10, 22, 42]
# [19, 16, 18, 17, 13, 20, 14, 14, 10, 22, 42, 21]
# [16, 18, 17, 13, 20, 14, 14, 10, 22, 42, 21, 20]
# [18, 17, 13, 20, 14, 14, 10, 22, 42, 21, 20, 11]
# [17, 13, 20, 14, 14, 10, 22, 42, 21, 20, 11, 8]
# ...

# %%
#house 6
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import statistics as st
plt.style.use('seaborn-poster')

x1=np.arange(1,43)
x2=np.arange(13,43)

y_init=[14,3,21,22,16,17,15,18,19,17,14,19]
y_test=[21,20,20,14,9,9,7,6,11,11,7,5,1,12,16,9,6,7,7,0,2,5,11,13,14,15,14,13,13,14]
yset=[14,3,21,22,16,17,15,18,19,17,14,19,21,20,20,14,9,9,7,6,11,11,7,5,1,12,16,9,6,7,7,0,2,5,11,13,14,15,14,13,13,14]
ez=[]
yx=[]
for i in range(0,30):
    z = np.polyfit(x1[i:12+i],y_init, 1)
    p = np.poly1d(z)
    y_init.append(y_test[i])
    y_init[0:12]=list(y_init[1:12])
    ez.append(p(12+i))
    print(y_init)
std=st.stdev(yset)
print('Std Dev:%.16f'%std)  
mae = mean_absolute_error(y_test, ez)
print('MAE: %f kwh' % mae)
mse =mean_squared_error(y_test,ez)
print('MSE:%.16f'%mse)
plt.scatter(x2,y_test,marker='o',color='black',label='Actual')
plt.xlabel('Month')
plt.ylabel('kWh')
plt.title('Household 6 Predicted Consumption')
plt.plot(x2,ez,'--Xb',label='Predicted')
plt.legend()
plt.show()
# Out:
# [3, 21, 22, 16, 17, 15, 18, 19, 17, 14, 19, 21]
# [21, 22, 16, 17, 15, 18, 19, 17, 14, 19, 21, 20]
# [22, 16, 17, 15, 18, 19, 17, 14, 19, 21, 20, 20]
# [16, 17, 15, 18, 19, 17, 14, 19, 21, 20, 20, 14]
# [17, 15, 18, 19, 17, 14, 19, 21, 20, 20, 14, 9]
# [15, 18, 19, 17, 14, 19, 21, 20, 20, 14, 9, 9]
# [18, 19, 17, 14, 19, 21, 20, 20, 14, 9, 9, 7]
# [19, 17, 14, 19, 21, 20, 20, 14, 9, 9, 7, 6]
# [17, 14, 19, 21, 20, 20, 14, 9, 9, 7, 6, 11]
# [14, 19, 21, 20, 20, 14, 9, 9, 7, 6, 11, 11]
# [19, 21, 20, 20, 14, 9, 9, 7, 6, 11, 11, 7]
# [21, 20, 20, 14, 9, 9, 7, 6, 11, 11, 7, 5]
# [20, 20, 14, 9, 9, 7, 6, 11, 11, 7, 5, 1]
# [20, 14, 9, 9, 7, 6, 11, 11, 7, 5, 1, 12]
# [14, 9, 9, 7, 6, 11, 11, 7, 5, 1, 12, 16]
# [9, 9, 7, 6, 11, 11, 7, 5, 1, 12, 16, 9]
# [9, 7, 6, 11, 11, 7, 5, 1, 12, 16, 9, 6]
# [7, 6, 11, 11, 7, 5, 1, 12, 16, 9, 6, 7]
# [6, 11, 11, 7, 5, 1, 12, 16, 9, 6, 7, 7]
# [11, 11, 7, 5, 1, 12, 16, 9, 6, 7, 7, 0]
# [11, 7, 5, 1, 12, 16, 9, 6, 7, 7, 0, 2]
# ...

# %%
#house 7
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import statistics as st
plt.style.use('seaborn-poster')

x1=np.arange(1,43)
x2=np.arange(13,43)

y_init=[64,58,58,46,66,60,52,94,110,112,86,80]
y_test=[87,76,72,55,80,67,73,88,116,94,54,84,98,102,100,78,75,90,66,76,97,95,86,96,93,91,77,83,78,76]
yset=[64,58,58,46,66,60,52,94,110,112,86,80,87,76,72,55,80,67,73,88,116,94,54,84,98,102,100,78,75,90,66,76,97,95,86,96,93,91,77,83,78,76]
ez=[]
yx=[]
for i in range(0,30):
    z = np.polyfit(x1[i:12+i],y_init, 1)
    p = np.poly1d(z)
    y_init.append(y_test[i])
    y_init[0:12]=list(y_init[1:12])
    ez.append(p(12+i))
    print(y_init)
std=st.stdev(yset)
print('Std Dev:%.16f'%std)  
mae = mean_absolute_error(y_test, ez)
print('MAE: %f kwh' % mae)
mse =mean_squared_error(y_test,ez)
print('MSE:%.16f'%mse)
plt.scatter(x2,y_test,marker='o',color='black',label='Actual')
plt.xlabel('Month')
plt.ylabel('kWh')
plt.title('Household 7 Predicted Consumption')
plt.plot(x2,ez,'--Xb',label='Predicted')
plt.legend()
plt.show()
# Out:
# [58, 58, 46, 66, 60, 52, 94, 110, 112, 86, 80, 87]
# [58, 46, 66, 60, 52, 94, 110, 112, 86, 80, 87, 76]
# [46, 66, 60, 52, 94, 110, 112, 86, 80, 87, 76, 72]
# [66, 60, 52, 94, 110, 112, 86, 80, 87, 76, 72, 55]
# [60, 52, 94, 110, 112, 86, 80, 87, 76, 72, 55, 80]
# [52, 94, 110, 112, 86, 80, 87, 76, 72, 55, 80, 67]
# [94, 110, 112, 86, 80, 87, 76, 72, 55, 80, 67, 73]
# [110, 112, 86, 80, 87, 76, 72, 55, 80, 67, 73, 88]
# [112, 86, 80, 87, 76, 72, 55, 80, 67, 73, 88, 116]
# [86, 80, 87, 76, 72, 55, 80, 67, 73, 88, 116, 94]
# [80, 87, 76, 72, 55, 80, 67, 73, 88, 116, 94, 54]
# [87, 76, 72, 55, 80, 67, 73, 88, 116, 94, 54, 84]
# [76, 72, 55, 80, 67, 73, 88, 116, 94, 54, 84, 98]
# [72, 55, 80, 67, 73, 88, 116, 94, 54, 84, 98, 102]
# [55, 80, 67, 73, 88, 116, 94, 54, 84, 98, 102, 100]
# [80, 67, 73, 88, 116, 94, 54, 84, 98, 102, 100, 78]
# [67, 73, 88, 116, 94, 54, 84, 98, 102, 100, 78, 75]
# [73, 88, 116, 94, 54, 84, 98, 102, 100, 78, 75, 90]
# ...

# %%
#house 8
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import statistics as st
plt.style.use('seaborn-poster')

x1=np.arange(1,43)
x2=np.arange(13,43)

y_init=[52,58,52,44,48,46,45,57,95,120,90,60]
y_test=[86,120,20,61,66,51,48,50,75,86,28,48,64,61,64,35,54,50,58,76,75,78,65,42,46,52,53,43,62,38]
yset=[52,58,52,44,48,46,45,57,95,120,90,60,86,120,20,61,66,51,48,50,75,86,28,48,64,61,64,35,54,50,58,76,75,78,65,42,46,52,53,43,62,38]
ez=[]
yx=[]
for i in range(0,30):
    z = np.polyfit(x1[i:12+i],y_init, 1)
    p = np.poly1d(z)
    y_init.append(y_test[i])
    y_init[0:12]=list(y_init[1:12])
    ez.append(p(12+i))
    print(y_init)
std=st.stdev(yset)
print('Std Dev:%.16f'%std)  
mae = mean_absolute_error(y_test, ez)
print('MAE: %f kwh' % mae)
mse =mean_squared_error(y_test,ez)
print('MSE:%.16f'%mse)
plt.scatter(x2,y_test,marker='o',color='black',label='Actual')
plt.xlabel('Month')
plt.ylabel('kWh')
plt.title('Household 8 Predicted Consumption')
plt.plot(x2,ez,'--Xb',label='Predicted')
plt.legend()
plt.show()
# Out:
# [58, 52, 44, 48, 46, 45, 57, 95, 120, 90, 60, 86]
# [52, 44, 48, 46, 45, 57, 95, 120, 90, 60, 86, 120]
# [44, 48, 46, 45, 57, 95, 120, 90, 60, 86, 120, 20]
# [48, 46, 45, 57, 95, 120, 90, 60, 86, 120, 20, 61]
# [46, 45, 57, 95, 120, 90, 60, 86, 120, 20, 61, 66]
# [45, 57, 95, 120, 90, 60, 86, 120, 20, 61, 66, 51]
# [57, 95, 120, 90, 60, 86, 120, 20, 61, 66, 51, 48]
# [95, 120, 90, 60, 86, 120, 20, 61, 66, 51, 48, 50]
# [120, 90, 60, 86, 120, 20, 61, 66, 51, 48, 50, 75]
# [90, 60, 86, 120, 20, 61, 66, 51, 48, 50, 75, 86]
# [60, 86, 120, 20, 61, 66, 51, 48, 50, 75, 86, 28]
# [86, 120, 20, 61, 66, 51, 48, 50, 75, 86, 28, 48]
# [120, 20, 61, 66, 51, 48, 50, 75, 86, 28, 48, 64]
# [20, 61, 66, 51, 48, 50, 75, 86, 28, 48, 64, 61]
# [61, 66, 51, 48, 50, 75, 86, 28, 48, 64, 61, 64]
# [66, 51, 48, 50, 75, 86, 28, 48, 64, 61, 64, 35]
# [51, 48, 50, 75, 86, 28, 48, 64, 61, 64, 35, 54]
# [48, 50, 75, 86, 28, 48, 64, 61, 64, 35, 54, 50]
# [50, 75, 86, 28, 48, 64, 61, 64, 35, 54, 50, 58]
# ...

# %%
#house 9
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import statistics as st
plt.style.use('seaborn-poster')

x1=np.arange(1,43)
x2=np.arange(13,43)

y_init=[248,238,263,218,220,206,182,204,214,217,183,220]
y_test=[189,188,186,209,209,209,212,249,253,222,128,209,191,221,198,193,226,197,196,286,258,233,222,202,220,237,266,297,170,169]
ez=[]
yset=[248,238,263,218,220,206,182,204,214,217,183,220,189,188,186,209,209,209,212,249,253,222,128,209,191,221,198,193,226,197,196,286,258,233,222,202,220,237,266,297,170,169]
yx=[]
for i in range(0,30):
    z = np.polyfit(x1[i:12+i],y_init, 1)
    p = np.poly1d(z)
    y_init.append(y_test[i])
    y_init[0:12]=list(y_init[1:12])
    ez.append(p(12+i))
    print(y_init)
std=st.stdev(yset)
print('Std Dev:%.16f'%std)  
mae = mean_absolute_error(y_test, ez)
print('MAE: %f kwh' % mae)
mse =mean_squared_error(y_test,ez)
print('MSE:%.16f'%mse)
plt.scatter(x2,y_test,marker='o',color='black',label='Actual')
plt.xlabel('Month')
plt.ylabel('kWh')
plt.title('Household 9 Predicted Consumption')
plt.plot(x2,ez,'--Xb',label='Predicted')
plt.legend()
plt.show()
# Out:
# [238, 263, 218, 220, 206, 182, 204, 214, 217, 183, 220, 189]
# [263, 218, 220, 206, 182, 204, 214, 217, 183, 220, 189, 188]
# [218, 220, 206, 182, 204, 214, 217, 183, 220, 189, 188, 186]
# [220, 206, 182, 204, 214, 217, 183, 220, 189, 188, 186, 209]
# [206, 182, 204, 214, 217, 183, 220, 189, 188, 186, 209, 209]
# [182, 204, 214, 217, 183, 220, 189, 188, 186, 209, 209, 209]
# [204, 214, 217, 183, 220, 189, 188, 186, 209, 209, 209, 212]
# [214, 217, 183, 220, 189, 188, 186, 209, 209, 209, 212, 249]
# [217, 183, 220, 189, 188, 186, 209, 209, 209, 212, 249, 253]
# [183, 220, 189, 188, 186, 209, 209, 209, 212, 249, 253, 222]
# [220, 189, 188, 186, 209, 209, 209, 212, 249, 253, 222, 128]
# [189, 188, 186, 209, 209, 209, 212, 249, 253, 222, 128, 209]
# [188, 186, 209, 209, 209, 212, 249, 253, 222, 128, 209, 191]
# [186, 209, 209, 209, 212, 249, 253, 222, 128, 209, 191, 221]
# [209, 209, 209, 212, 249, 253, 222, 128, 209, 191, 221, 198]
# ...

# %%
#house 10
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import statistics as st
plt.style.use('seaborn-poster')

x1=np.arange(1,43)
x2=np.arange(13,43)

y_init=[76,74,77,51,68,75,62,84,104,62,70,78]
y_test=[52,82,72,60,82,66,68,131,107,130,55,76,80,82,87,68,88,69,85,24,63,75,71,82,87,83,119,95,70,39]
yset=[76,74,77,51,68,75,62,84,104,62,70,78,52,82,72,60,82,66,68,131,107,130,55,76,80,82,87,68,88,69,85,24,63,75,71,82,87,83,119,95,70,39]
ez=[]
yx=[]
for i in range(0,30):
    z = np.polyfit(x1[i:12+i],y_init, 1)
    p = np.poly1d(z)
    y_init.append(y_test[i])
    y_init[0:12]=list(y_init[1:12])
    ez.append(p(12+i))
    print(y_init)
std=st.stdev(yset)
print('Std Dev:%.16f'%std)  
mae = mean_absolute_error(y_test, ez)
print('MAE: %f kwh' % mae)
mse =mean_squared_error(y_test,ez)
print('MSE:%.16f'%mse)
plt.scatter(x2,y_test,marker='o',color='black',label='Actual')
plt.xlabel('Month')
plt.ylabel('kWh')
plt.title('Household 10 Predicted Consumption')
plt.plot(x2,ez,'--Xb',label='Predicted')
plt.legend()
plt.show()
# Out:
# [74, 77, 51, 68, 75, 62, 84, 104, 62, 70, 78, 52]
# [77, 51, 68, 75, 62, 84, 104, 62, 70, 78, 52, 82]
# [51, 68, 75, 62, 84, 104, 62, 70, 78, 52, 82, 72]
# [68, 75, 62, 84, 104, 62, 70, 78, 52, 82, 72, 60]
# [75, 62, 84, 104, 62, 70, 78, 52, 82, 72, 60, 82]
# [62, 84, 104, 62, 70, 78, 52, 82, 72, 60, 82, 66]
# [84, 104, 62, 70, 78, 52, 82, 72, 60, 82, 66, 68]
# [104, 62, 70, 78, 52, 82, 72, 60, 82, 66, 68, 131]
# [62, 70, 78, 52, 82, 72, 60, 82, 66, 68, 131, 107]
# [70, 78, 52, 82, 72, 60, 82, 66, 68, 131, 107, 130]
# [78, 52, 82, 72, 60, 82, 66, 68, 131, 107, 130, 55]
# [52, 82, 72, 60, 82, 66, 68, 131, 107, 130, 55, 76]
# [82, 72, 60, 82, 66, 68, 131, 107, 130, 55, 76, 80]
# [72, 60, 82, 66, 68, 131, 107, 130, 55, 76, 80, 82]
# [60, 82, 66, 68, 131, 107, 130, 55, 76, 80, 82, 87]
# [82, 66, 68, 131, 107, 130, 55, 76, 80, 82, 87, 68]
# [66, 68, 131, 107, 130, 55, 76, 80, 82, 87, 68, 88]
# [68, 131, 107, 130, 55, 76, 80, 82, 87, 68, 88, 69]
# ...

# %%
#house 1
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

plt.style.use('seaborn-poster')

x1=np.arange(1,43)
x2=np.arange(13,43)
xz=np.arange(1,13)

y_init=[15,19,15,22,35,31,27,25,32,21,11,5]
y_test=[7,18,17,23,20,22,19,17,19,22,23,19,24,14,15,19,23,20,16,19,17,21,15,12,14,11,12,15,21,19]
ez=[]

y_init2=[9,11,7,9,20,7,11,15,29,17,8,8]
y_test2=[9,16,12,10,19,12,12,24,34,10,7,6,9,19,10,7,17,18,14,18,38,13,17,26,18,25,22,20,31,16]
ez2=[]

y_init3=[25,22,24,21,19,19,21,16,22,20,22,21]
y_test3=[22,16,21,16,16,21,23,27,56,33,20,28,31,39,33,11,6,12,12,32,49,37,29,34,31,32,31,21,21,21]
ez3=[]

y_init4=[9,9,11,9,21,11,9,8,7,6,9,6]
y_test4=[7,5,6,7,6,5,7,5,4,4,3,5,4,4,7,11,8,10,7,8,6,8,7,9,9,7,7,6,11,10]
ez4=[]

y_init5=[23,0,14,19,14,28,23,28,26,12,21,19]
y_test5=[18,19,20,19,19,16,18,17,13,20,14,14,10,22,42,21,20,11,8,7,7,12,8,9,9,9,7,5,13,10]
ez5=[]

y_init6=[14,3,21,22,16,17,15,18,19,17,14,19]
y_test6=[21,20,20,14,9,9,7,6,11,11,7,5,1,12,16,9,6,7,7,0,2,5,11,13,14,15,14,13,13,14]
ez6=[]

y_init7=[64,58,58,46,66,60,52,94,110,112,86,80]
y_test7=[87,76,72,55,80,67,73,88,116,94,54,84,98,102,100,78,75,90,66,76,97,95,86,96,93,91,77,83,78,76]
ez7=[]

y_init8=[52,58,52,44,48,46,45,57,95,120,90,60]
y_test8=[86,120,20,61,66,51,48,50,75,86,28,48,64,61,64,35,54,50,58,76,75,78,65,42,46,52,53,43,62,38]
ez8=[]

y_init9=[248,238,263,218,220,206,182,204,214,217,183,220]
y_test9=[189,188,186,209,209,209,212,249,253,222,128,209,191,221,198,193,226,197,196,286,258,233,222,202,220,237,266,297,170,169]
ez9=[]

y_init10=[76,74,77,51,68,75,62,84,104,62,70,78]
y_test10=[52,82,72,60,82,66,68,131,107,130,55,76,80,82,87,68,88,69,85,24,63,75,71,82,87,83,119,95,70,39]
ez10=[]



for i in range(0,30):
    z = np.polyfit(x1[i:12+i],y_init, 1)
    p = np.poly1d(z)
    y_init.append(y_test[i])
    y_init[0:12]=list(y_init[1:12])
    ez.append(p(12+i))
    
for i in range(0,30):
    z = np.polyfit(x1[i:12+i],y_init2, 1)
    p = np.poly1d(z)
    y_init2.append(y_test2[i])
    y_init2[0:12]=list(y_init2[1:12])
    ez2.append(p(12+i))

for i in range(0,30):
    z = np.polyfit(x1[i:12+i],y_init3, 1)
    p = np.poly1d(z)
    y_init3.append(y_test3[i])
    y_init3[0:12]=list(y_init3[1:12])
    ez3.append(p(12+i))
    
for i in range(0,30):
    z = np.polyfit(x1[i:12+i],y_init4, 1)
    p = np.poly1d(z)
    y_init4.append(y_test4[i])
    y_init4[0:12]=list(y_init4[1:12])
    ez4.append(p(12+i))
    
for i in range(0,30):
    z = np.polyfit(x1[i:12+i],y_init5, 1)
    p = np.poly1d(z)
    y_init5.append(y_test5[i])
    y_init5[0:12]=list(y_init5[1:12])
    ez5.append(p(12+i))
    
for i in range(0,30):
    z = np.polyfit(x1[i:12+i],y_init6, 1)
    p = np.poly1d(z)
    y_init6.append(y_test6[i])
    y_init6[0:12]=list(y_init6[1:12])
    ez6.append(p(12+i))
    
for i in range(0,30):
    z = np.polyfit(x1[i:12+i],y_init7, 1)
    p = np.poly1d(z)
    y_init7.append(y_test7[i])
    y_init7[0:12]=list(y_init7[1:12])
    ez7.append(p(12+i))
    
for i in range(0,30):
    z = np.polyfit(x1[i:12+i],y_init8, 1)
    p = np.poly1d(z)
    y_init8.append(y_test8[i])
    y_init8[0:12]=list(y_init8[1:12])
    ez8.append(p(12+i))
    
for i in range(0,30):
    z = np.polyfit(x1[i:12+i],y_init9, 1)
    p = np.poly1d(z)
    y_init9.append(y_test9[i])
    y_init9[0:12]=list(y_init9[1:12])
    ez9.append(p(12+i))
    
for i in range(0,30):
    z = np.polyfit(x1[i:12+i],y_init10, 1)
    p = np.poly1d(z)
    y_init10.append(y_test10[i])
    y_init10[0:12]=list(y_init10[1:12])
    ez10.append(p(12+i))
    
plt.figure(1)    
plt.subplot(2,2,1)
plt.plot(x2,y_test,'or',label='Actual')
plt.plot(x2,ez,'-ok',label='Predicted')
plt.title('Household 1')
plt.ylabel('kWh')
plt.legend(loc='upper left')

plt.subplot(2,2,2)
plt.plot(x2,y_test2,'or',label='Actual')
plt.plot(x2,ez2,'-ok',label='Predicted')
plt.title('Household 2')
plt.legend(loc='upper left')

plt.figure(2)
plt.subplot(2,2,1)
plt.plot(x2,y_test3,'or',label='Actual')
plt.plot(x2,ez3,'-ok',label='Predicted')
plt.title('Household 3')
plt.ylabel('kWh')
plt.legend(loc='upper left')

plt.subplot(2,2,2)
plt.plot(x2,y_test4,'or',label='Actual')
plt.plot(x2,ez4,'-ok',label='Predicted')
plt.title('Household 4')
plt.legend(loc='upper left')

plt.figure(3)
plt.subplot(2,2,1)
plt.plot(x2,y_test5,'or',label='Actual')
plt.plot(x2,ez5,'-ok',label='Predicted')
plt.title('Household 5')
plt.ylabel('kWh')
plt.legend(loc='upper left')

plt.subplot(2,2,2)
plt.plot(x2,y_test6,'or',label='Actual')
plt.plot(x2,ez6,'-ok',label='Predicted')
plt.title('Household 6')
plt.legend(loc='upper left')

plt.figure(4)
plt.subplot(2,2,1)
plt.plot(x2,y_test7,'or',label='Actual')
plt.plot(x2,ez7,'-ok',label='Predicted')
plt.title('Household 7')
plt.ylabel('kWh')
plt.legend(loc='upper left')

plt.subplot(2,2,2)
plt.plot(x2,y_test8,'or',label='Actual')
plt.plot(x2,ez8,'-ok',label='Predicted')
plt.title('Household 8')
plt.legend(loc='upper left')

plt.figure(5)
plt.subplot(2,2,1)
plt.plot(x2,y_test9,'or',label='Actual')
plt.plot(x2,ez9,'-ok',label='Predicted')
plt.title('Household 9')
plt.ylabel('kWh')
plt.legend(loc='upper left')
plt.xlabel('Month')
plt.subplot(2,2,2)
plt.plot(x2,y_test10,'or',label='Actual')
plt.plot(x2,ez10,'-ok',label='Predicted')
plt.title('Household 10')
plt.legend(loc='upper left')
plt.xlabel('Month')

er=np.subtract(y_test,ez)
er2=np.subtract(y_test2,ez2)
er3=np.subtract(y_test3,ez3)
er4=np.subtract(y_test4,ez4)
er5=np.subtract(y_test5,ez5)
er6=np.subtract(y_test6,ez6)
er7=np.subtract(y_test7,ez7)
er8=np.subtract(y_test8,ez8)
er9=np.subtract(y_test9,ez9)
er10=np.subtract(y_test10,ez10)

plt.figure(6)
plt.subplot(3,2,1)
plt.plot(x2,er,'-ok',label='House 1')
plt.legend(loc='upper left')
plt.subplot(3,2,2)
plt.plot(x2,er2,'-ok',label='House 2')
plt.legend(loc='upper left')
plt.subplot(3,2,3)
plt.plot(x2,er3,'-ok',label='House 3')
plt.legend(loc='upper left')
plt.subplot(3,2,4)
plt.plot(x2,er4,'-ok',label='House 4')
plt.legend(loc='upper left')
plt.subplot(3,2,5)
plt.plot(x2,er5,'-ok',label='House 5')
plt.ylabel('kWh')
plt.legend(loc='upper left')
plt.subplot(3,2,6)
plt.plot(x2,er6,'-ok',label='House 6')
plt.legend(loc='upper left')
plt.figure(7)
plt.subplot(3,2,1)
plt.plot(x2,er7,'-ok',label='House 7')
plt.legend(loc='upper left')
plt.subplot(3,2,2)
plt.plot(x2,er8,'-ok',label='House 8')
plt.legend(loc='upper left')
plt.subplot(3,2,3)
plt.plot(x2,er9,'-ok',label='House 9')
plt.legend(loc='upper left')
plt.subplot(3,2,4)
plt.plot(x2,er10,'-ok',label='House 10')
plt.legend(loc='upper left')

z = np.polyfit(xz,y_init, 1)
p = np.poly1d(z)
z2 = np.polyfit(xz,y_init2, 1)
p2 = np.poly1d(z2)
z3 = np.polyfit(xz,y_init3, 1)
p3 = np.poly1d(z3)
z4 = np.polyfit(xz,y_init4, 1)
p4 = np.poly1d(z4)
z5 = np.polyfit(xz,y_init5, 1)
p5 = np.poly1d(z5)
plt.figure(8)
plt.subplot(2,2,1)
plt.plot(xz,y_init,'or',label='Data')
plt.plot(xz,p(xz),'b',label='Model')
plt.title('House 1')
plt.ylabel('kWh')
plt.xlabel('Month')
plt.legend(loc='upper right')
plt.subplot(2,2,2)
plt.plot(xz,y_init2,'or',label='Data')
plt.plot(xz,p2(xz),'b',label='Model')
plt.title('House 2')
plt.ylabel('kWh')
plt.xlabel('Month')
plt.legend()

plt.show()
